# %% [markdown]
# #Theory Questions

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#
# - >Interpreted Languages:
#
#   Code is executed line-by-line using an interpreter.
#
#   Slower compared to compiled languages as each line is processed at runtime.
#
# Example languages :  Python, JavaScript, Ruby.
#
#
# - >Compiled Languages:
#
#    Code is converted into machine code by a compiler before execution.
#
#    Faster execution as the machine code is directly executed by the CPU.
#
# Example languages : C, C++, Java (compiled into bytecode, then interpreted by JVM).
#
# 2. What is exception handling in Python?
#
#   Exception handling is a mechanism to handle runtime errors in a program without terminating it unexpectedly.
#
#   In Python, exceptions are handled using:
#
#   try: Defines a block of code to monitor for errors.
#
#   except: Handles the exception if it occurs.
#
#   else: Executes if no exception occurs.
#
#   finally: Executes regardless of whether an exception occurs (used for cleanup).
#
#
# 3. What is the purpose of the finally block in exception handling?
#
#  The finally block is used to define code that will always execute, regardless of whether an exception occurred in the try block.
#  Commonly used for cleanup tasks, such as closing files or releasing resources.
#
#
#
# 4. What is logging in Python?
#
#  Logging is a process of recording events, warnings, and errors that occur during program execution.
# Python's logging module allows developers to track program behavior, debug errors, and generate log files.
#
#  It supports various levels: DEBUG, INFO, WARNING, ERROR, CRITICAL.
#
#
# 5. What is the significance of the _del_ method in Python?
#
#  The _del_ method is a special method in Python called when an object is about to be destroyed.Useful for resource cleanup tasks, such as closing database connections or files.
#
#
# 6. What is the difference between import and from ... import in Python?
#
#  import: Imports the entire module, requiring you to prefix module names when accessing functions or classes.
#
#  from ... import: Imports specific functions, classes, or variables, allowing direct usage.
#
#
# 7. How can you handle multiple exceptions in Python?
#
#  Use a tuple to handle multiple exceptions in a single except block.
#
#
#
# 8. What is the purpose of the with statement when handling files in Python?
#
#  The with statement simplifies file handling by automatically managing resources, such as closing files.
#  Ensures that the file is closed after the block execution, even if an exception occurs.
#
#
#
# 9. What is the difference between multithreading and multiprocessing?
#
# - >Multithreading:
#
#  Multiple threads within the same process share the same memory space.
#
#  Useful for I/O-bound tasks (e.g., file reading, web scraping).
#
#
# - >Multiprocessing:
#
#  Each process has its own memory space, making it ideal for CPU-bound tasks (e.g., computations).
#  Avoids the Global Interpreter Lock (GIL) in Python.
#
#
# 10. What are the advantages of using logging in a program?
#
#  Tracks program flow and errors.
#
#  Useful for debugging and monitoring in production environments.
#
#  Allows categorization of messages by severity levels (DEBUG, INFO, ERROR).
#
#
#
# 11. What is memory management in Python?
#
#  Python uses automatic memory management with a combination of reference counting and garbage collection.
#
#  Objects are removed from memory when their reference count drops to zero.
#
#  Garbage collection handles cyclic references.
#
#
#
# 12. What are the basic steps involved in exception handling in Python?
#
#  Try block: Code where an exception might occur.
#
#  Except block: Handles the exception if it occurs.
#
#  Else block: Executes when no exception occurs in the try block.
#
#  Finally block: Executes cleanup code regardless of an exception.
#
#
# 13. Why is memory management important in Python?
#
#  Efficient memory management ensures optimal utilization of system resources, preventing memory leaks and ensuring program stability.
#
#  Python automates memory allocation and deallocation using a combination of reference counting and garbage collection, which reduces the burden on developers.
#
#  Without proper memory management, unused objects may consume resources, leading to slower performance or crashes.
#
#
#
# 14. What is the role of try and except in exception handling?
#
#  try block: Contains the code that might raise an exception.
#
#  except block: Handles the exception and prevents the program from crashing.
#
#  Together, they allow developers to anticipate and respond to runtime errors.
#
#
#
# 15. How does Python's garbage collection system work?
#
#  Python uses reference counting to track the number of references to an object. When the count drops to zero, the memory is deallocated.
#
#  Additionally, Python’s garbage collector detects and cleans up cyclic references (objects referring to each other).
#
#  Developers can manually invoke garbage collection using the gc module:
#  import gc
#  gc.collect()
#
#
#
# 16. What is the purpose of the else block in exception handling?
#
#  The else block executes if no exceptions are raised in the try block.
#
#  It is used to define code that should only run when the try block succeeds.
#
#
# 17. What are the common logging levels in Python?
#
#  DEBUG: Detailed diagnostic information.
#
#  INFO: General information about program execution.
#
#  WARNING: An indication of potential problems.
#
#  ERROR: A serious issue that prevents execution of part of the program.
#
#  CRITICAL: A severe error causing program failure.
#
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
#  os.fork():
#
#  Creates a new process by duplicating the current process.
#
#  Available only on Unix-like systems.
#
#  Requires manual management of resources and process synchronization.
#
#
# - >Multiprocessing:
#
#   A higher-level library for creating and managing processes.
#
#   Works on all platforms and provides features like process pools and inter-process communication.
#
#
#
#
# 19. What is the importance of closing a file in Python?
#
#  Prevents data loss by ensuring all changes are saved to the file.
#
#  Frees up system resources.
#
#  Avoids file corruption and ensures other processes can access the file.
#
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
#  file.read(): Reads the entire content of the file as a single string.
#
#  file.readline(): Reads one line from the file at a time.
#
#
# 21. What is the logging module in Python used for?
#
#  The logging module provides a flexible framework for logging messages during program execution.
#
#  It helps in debugging, tracking events, and monitoring production systems.
#
#  Logs can be directed to files, consoles, or remote servers.
#
#
#
# 22. What is the os module in Python used for in file handling?
#
#  The os module provides functions to interact with the operating system, including file handling tasks such as:
#
#  Checking if a file exists (os.path.exists()).
#
#  Renaming or deleting files (os.rename(), os.remove()).
#
#  Creating and navigating directories (os.mkdir(), os.chdir()).
#
#
#
# 23. What are the challenges associated with memory management in Python?
#
#  Cyclic references: Objects referring to each other may not be immediately garbage collected.
#
#  Memory leaks: Improper use of global variables or long-lived objects can lead to memory not being freed.
#
#  Inefficiency: Automatic memory management may be slower compared to manual management in certain situations.
#
# 24. How do you raise an exception manually in Python?
#
#  Use the raise statement to throw an exception.
#
#  Example:
#
# age = -5
# if age < 0:
#     raise ValueError("Age cannot be negative!")
#
#
# 25. Why is it important to use multithreading in certain applications?
#
#  Multithreading allows multiple tasks to run concurrently within a single process, making programs more efficient.
#
#  Useful for I/O-bound tasks, such as file reading or network requests, where threads can work while waiting for resources.

# %% [markdown]
# #Practical Questions

# %% [markdown]
# 1. How can you open a file for writing in Python and write a string to it?

# %%
 with open("example.txt","w") as file:
  file.write("Hello, World")

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line.

# %%
with open("example.txt","r") as file:
  for line in file:
    print(line)
# Out:
# Hello, World

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
  with open("non_existent_file.txt","r") as file:
    print(file.read())
except FileNotFoundError:
  print("File not found")
# Out:
# File not found

# %% [markdown]
# 4.Write a Python script that reads from one file and writes its content to another file

# %%
with open("source.txt","w") as file:
  file.write("this content is in the source of file")

with open("source.txt", "r") as src, open("destination.txt", "w") as dest:
    dest.write(src.read())

# %% [markdown]
# 5.How would you catch and handle division by zero error in Python?

# %%
try:
  result = 10/0
except ZeroDivisionError:
  print("Division error is not allowed.")
# Out:
# Division error is not allowed.

# %% [markdown]
# 6.Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging
logging.basicConfig(filename="errors.log", level=logging.ERROR)
try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Attempted division by zero.")
# Out:
# ERROR:root:Attempted division by zero.

# %% [markdown]
#  7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
logging.basicConfig(level=logging.DEBUG)
logging.debug("Debugging information")
logging.info("General info")
logging.warning("Warning message")
logging.error("Error occurred")
logging.critical("Critical issue")
# Out:
# WARNING:root:Warning message
# ERROR:root:Error occurred
# CRITICAL:root:Critical issue

# %% [markdown]
# 8.Write a program to handle a file opening error using exception handling.

# %%
try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Error: The file does not exist.

# %% [markdown]
#  9.How can you read a file line by line and store its content in a list in Python?

# %%
lines = []
with open("example.txt", "r") as file:
  for line in file:
    lines.append(line.strip())
print(lines)
# Out:
# ['Hello, World']

# %% [markdown]
#  10.How can you append data to an existing file in Python?

# %%
with open("example.txt", "a") as file:
  file.write("\nthis is the first line.")

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist.

# %%
data = {"namae": "ajay", "course": "DA"}
try:
  print(data["age"])
except KeyError:
  print("key not found")
# Out:
# key not found

# %% [markdown]
# 12.Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
try:
  result = 10/0
  num = int("abc")
except ZeroDivisionError:
  print("Division error is not allowed")
except ValueError:
  print("Invalid value")
# Out:
# Division error is not allowed

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?

# %%
import os
if os.path.exists("example.txt"):
    with open("example.txt", "r") as file:
        print(file.read())
else:
    print("The file does not exist.")
# Out:
# Hello, Worldthis is the first line.this is the first line.this is the first line.
# this is the first line.

# %% [markdown]
# 14.Write a program that uses the logging module to log both informational and error messages.

# %%
import logging

logging.basicConfig(filename="app.log", level=logging.DEBUG)
logging.info("This is an informational message.")
try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("An error occurred: Division by zero.")
# Out:
# ERROR:root:An error occurred: Division by zero.

# %% [markdown]
# 15.Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
try:
    with open("example.txt", "r") as file:
        content = file.read()
        if not content:
            print("The file is empty.")
        else:
            print(content)
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Hello, Worldthis is the first line.this is the first line.this is the first line.
# this is the first line.

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
# !pip install memory_profiler


@profile
def memory_intensive_task():
    nums = [i for i in range(100000)]
    print("Task completed.")

memory_intensive_task()
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-733e7c7cedd1> in <cell line: 4>()
#       2
#       3
# ----> 4 @profile
#       5 def memory_intensive_task():
#       6     nums = [i for i in range(100000)]
#
# NameError: name 'profile' is not defined

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
numbers = [1,2,3,4]
with open("numbers.txt", "w") as file:
  for num in numbers:
    file.write(f"{num}\n")

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("app.log", maxBytes=1_000_000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.DEBUG)
logging.info("This is a log message.")

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block.

# %%
data = {"name": "Alice"}
list_data = [1, 2, 3]
try:
    print(list_data[5])  # IndexError
    print(data["age"])  # KeyError
except IndexError:
    print("Error: List index out of range.")
except KeyError:
    print("Error: Dictionary key not found.")
# Out:
# Error: List index out of range.

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python?

# %%
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, Worldthis is the first line.this is the first line.this is the first line.
# this is the first line.

# %% [markdown]
# 21.Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
word_to_find = "example"
with open("example.txt", "r") as file:
    content = file.read()
    count = content.count(word_to_find)
    print(f"The word '{word_to_find}' occurs {count} times.")
# Out:
# The word 'example' occurs 0 times.

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents.

# %%
import os
if os.path.exists("example.txt") and os.stat("example.txt").st_size > 0:
    with open("example.txt", "r") as file:
        print(file.read())
else:
    print("The file is either empty or does not exist.")
# Out:
# Hello, Worldthis is the first line.this is the first line.this is the first line.
# this is the first line.

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

logging.basicConfig(filename="file_errors.log", level=logging.ERROR)

try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    logging.error("File not found error occurred.")
# Out:
# ERROR:root:File not found error occurred.
